# %%
import json
import hmac
import uuid
import hmac
import time
import base64
import hashlib
import datetime
import requests
import pandas as pd
from urllib.parse import quote
from configparser import ConfigParser

baseInstances = ["9d4c9fd55d884badba2540b561432c1e", "75e4db20cafe4da592a1d3bbed5f82ef", "4ab44591456440e6888ac2b3130a5151", "3f362725b29d4943b894f98f6155c6db", "952dbd0188ff4603b94c81f69398ed75"]

# %%
class SignatureUrl():
    """python 计算openapi的签名"""

    def __init__(self, public_param, private_param, secret):
        self.public_param = public_param
        self.private_param = private_param
        self.secret = secret

    def get_timestamp(self):
        time_format = "%Y-%m-%dT%H:%M:%SZ"
        return datetime.datetime.utcnow().strftime(time_format)

    def get_uuid(self):
        return str(uuid.uuid1())

    def url_encode_str(self, all_params):
        sort_all_params = list()
        for key, value in all_params.items():
            params = key + '=' + value
            sort_all_params.append(params)
        # 对参数进行升序排序
        sort_all_params.sort()

        for i in range(len(sort_all_params)):
            # 对参数以及参数值进行urlencode处理,注意:’=‘此时不能处理，否则后面会再次对%3D进行encode
            sort_all_params[i] = quote(sort_all_params[i], '=')
            # 对encode之后的字符串进行再处理
            tmp = sort_all_params[i]
            if tmp.find('+'):
                tmp.replace('+','%20')
            elif tmp.find('*'):
                tmp.replace('*','%2A')
            elif tmp.find('%7E'):
                tmp.replace('%7E','~')
            
            sort_all_params[i] = tmp
        return sort_all_params

    def get_signature(self, param, http_method, AccesskeySecret):
        str_to_sign = ''
        sort_all_params = self.url_encode_str(param)
        #print(sort_all_params)
        for i in range(len(sort_all_params)):
            str_to_sign = str_to_sign + sort_all_params[i] + '&'

        # 将最后一位&给截取掉
        str_to_sign = http_method + '&%2F&' + quote(str_to_sign[:-1])
        #print(str_to_sign)
        key = AccesskeySecret+'&'
        signature = hmac.new(key.encode(
            'utf-8'), str_to_sign.encode('utf-8'), digestmod=hashlib.sha1)
        signature = base64.b64encode(signature.digest()).decode().rstrip("\n")
        # 解决签名中包含有'+'的特殊情况
        signature = list(signature)
        for i in range(len(signature)):
            #signature[i] = str(signature[i])
            if signature[i] == '+':
                signature[i] = '%2B'
        newSignature = ''.join(signature)
        #print ("Signature: " + newSignature)
        self.private_param['Signature'] = newSignature

    def url_factory(self, method):
        all_params = dict(self.public_param, **self.private_param)
        self.get_signature(all_params, method, self.secret)
        url = ''
        par=[]
        for key, value in all_params.items():
            params = key + '=' + value
            par.append(params)
        for i in range(len(par)):
            url = url + par[i] + '&'
        url = 'http://swas.eu-central-1.aliyuncs.com?' + url[:-1] + '&Signature=' + self.private_param['Signature']
        #print('url is : ' + url)
        return url

# %%
def config(filename='alibaba_tokens.prod', section='tokens'):
    # create a parser
    parser = ConfigParser()
    # read config file
    parser.read(filename)

    # get section, default to postgresql
    cfg = {}
    if parser.has_section(section):
        params = parser.items(section)
        for param in params:
            cfg[param[0]] = param[1]
    else:
        raise Exception('Section {0} not found in the {1} file'.format(section, filename))
    return cfg

def upgradeInstance(InstanceId, ImageId, public_param, secret):
    action_param = dict()
    action_param["Action"] = "ResetSystem"

    private_param = dict()
    private_param["Action"] = action_param["Action"]
    private_param["InstanceId"] = InstanceId
    private_param["ImageId"] = ImageId

    sig = SignatureUrl(public_param, private_param, secret)
    sig.public_param["Timestamp"] = sig.get_timestamp()
    sig.public_param["SignatureNonce"] = sig.get_uuid()
    url = sig.url_factory('GET')

    result = requests.request(method="get",url=url)

    print("Instance reset: " + result.text)

def renameInstance(InstanceId, Name, public_param, secret):
    action_param = dict()
    action_param["Action"] = "UpdateInstanceAttribute"

    private_param = dict()
    private_param["Action"] = action_param["Action"]
    private_param["InstanceId"] = InstanceId
    private_param["InstanceName"] = Name

    sig = SignatureUrl(public_param, private_param, secret)
    sig.public_param["Timestamp"] = sig.get_timestamp()
    sig.public_param["SignatureNonce"] = sig.get_uuid()
    url = sig.url_factory('GET')

    result = requests.request(method="get",url=url)

    print("Instance renamed: " + result.text)

def startInstance(InstanceId, public_param, secret):
    action_param = dict()
    action_param["Action"] = "StartInstance"

    private_param = dict()
    private_param["Action"] = action_param["Action"]
    private_param["InstanceId"] = InstanceId


    sig = SignatureUrl(public_param, private_param, secret)
    sig.public_param["Timestamp"] = sig.get_timestamp()
    sig.public_param["SignatureNonce"] = sig.get_uuid()
    url = sig.url_factory('GET')

    result = requests.request(method="get",url=url)

    print("Instance started: " + result.text)

def stopInstance(InstanceId, public_param, secret):
    action_param = dict()
    action_param["Action"] = "StopInstance"

    private_param = dict()
    private_param["Action"] = action_param["Action"]
    private_param["InstanceId"] = InstanceId


    sig = SignatureUrl(public_param, private_param, secret)
    sig.public_param["Timestamp"] = sig.get_timestamp()
    sig.public_param["SignatureNonce"] = sig.get_uuid()
    url = sig.url_factory('GET')

    result = requests.request(method="get",url=url)

    print("Instance released: " + result.text)


def rebootInstance(InstanceId, public_param, secret):
    action_param = dict()
    action_param["Action"] = "RebootInstance"

    private_param = dict()
    private_param["Action"] = action_param["Action"]
    private_param["InstanceId"] = InstanceId


    sig = SignatureUrl(public_param, private_param, secret)
    sig.public_param["Timestamp"] = sig.get_timestamp()
    sig.public_param["SignatureNonce"] = sig.get_uuid()
    url = sig.url_factory('GET')

    result = requests.request(method="get",url=url)

    print("Instance rebooted: " + result.text)

# %% [markdown]
# # Start/stop/reboot/reset/list all instances

# %%
params = config()
mode = "reboot" # start or stop or reboot or reset or list

ratio = 1.0

public_param = dict()
public_param["AccessKeyId"] = params["id"]
public_param["SignatureMethod"] = 'HMAC-SHA1'
public_param["SignatureVersion"] = '1.0'
public_param["Version"] = "2020-06-01"
public_param["Format"] = 'json'

action_param = dict()
action_param["Action"] = "ListInstances"

instances = []
j=0
k=0
for i in range(2):
    private_param = dict()
    private_param["Action"] = action_param["Action"]
    private_param["RegionId"] = "eu-central-1"
    private_param["PageSize"] = "100"
    private_param["PageNumber"] = str(i+1)

    sig = SignatureUrl(public_param, private_param, params["secret"])
    sig.public_param["Timestamp"] = sig.get_timestamp()
    sig.public_param["SignatureNonce"] = sig.get_uuid()
    url = sig.url_factory('GET')
    for _ in range(5):
        result = requests.request(method="get",url=url)
        if result.status_code == 200:
            print(f"page {i} attempt failed")
            break
        time.sleep(20)
    
    print(f"page {i} appended")
    
    instances = instances + json.loads(result.text)["Instances"]

if mode == "list":
    df = pd.json_normalize( json.loads(result.text), record_path = ['Instances'] )
    df.to_csv("alibaba_instances.csv", index=None)
else:
        
    for instance in instances:
        print(str(j+k) + ". " + instance["InstanceId"])

        if instance["InstanceId"] not in baseInstances:
            if mode == "start":
                if instance["Status"] == "Stopped":
                    startInstance(instance["InstanceId"], public_param, params["secret"])
            elif mode == "stop":
                if instance["Status"] == "Running":
                    stopInstance(instance["InstanceId"], public_param, params["secret"])
            elif mode == "reboot":
                if 1 == 1:
                    j += 1
                    rebootInstance(instance["InstanceId"], public_param, params["secret"])
                    renameInstance(instance["InstanceId"], "nolang_v1_" + str(j), public_param, params["secret"])
                    print ("instance was rebooted")
                else:
                    k+=1
                    renameInstance(instance["InstanceId"], "overquota_" + str(k), public_param, params["secret"])
                    print ("instance inactive")
            elif mode == "reset":
                j += 1
                print(str(j) + ". " + instance["InstanceId"] + " has ImageId " + instance["InstanceId"])
                time.sleep(0.5)
                if instance["InstanceId"] not in baseInstances: # and instance["Status"] == "Running":
                    if j/len(instances) < ratio:
                        upgradeInstance(instance["InstanceId"], database_nolang, public_param, params["secret"])
                        renameInstance(instance["InstanceId"], "nolang_v1_" + str(j), public_param, params["secret"])
                    else:
                        upgradeInstance(instance["InstanceId"], database_ml, public_param, params["secret"])
                        renameInstance(instance["InstanceId"], "intl_v1_" + str(j), public_param, params["secret"])
                    time.sleep(8)
        else:
            pass
        time.sleep(8)
# Out:
# page 0 attempt failed
# page 0 appended
# page 1 attempt failed
# page 1 appended
# 0. 871f1413519c4cf98f3356df3b9cc07a
# Instance rebooted: {"RequestId":"3DD1683B-5989-34A5-A53B-41DA00E52FA8"}
# Instance renamed: {"RequestId":"C8908A38-3C6E-3293-84E1-10F66E62BEFB"}
# instance was rebooted
# 1. 16c7f98d6cdb4a9d9856ccd3eecf298e
# Instance rebooted: {"RequestId":"A5BDFA1A-BDE5-3BCB-BA63-60420A894B9F"}
# Instance renamed: {"RequestId":"96DC3ED5-9C87-317E-A6B5-1143A43521A6"}
# instance was rebooted
# 2. b987a38e5a6a4e80a88bb083619ef167
# Instance rebooted: {"RequestId":"9050DD26-F6A4-37CF-9CCE-80EEE19B66B9"}
# Instance renamed: {"RequestId":"AF1FC978-4F8D-34E0-B549-8B32640A23A7"}
# instance was rebooted
# 3. 52a951602a284b03b1ddcea48ae6ee10
# Instance rebooted: {"RequestId":"17C016A1-5777-321F-905D-99A664D50827"}
# Instance renamed: {"RequestId":"79A15C7C-C893-39C0-910E-F94205A6D599"}
# instance was rebooted
# 4. b8a41cf7c16747948c95ffeca34376aa
# Instance rebooted: {"RequestId":"E7A82B5E-684D-3193-B0D4-857892786023"}
# Instance renamed: {"RequestId":"BD00F337-50FD-3C2E-ADF8-FA2A0C91FB7B"}
# instance was rebooted
# 5. 9a027889c0cc488ba40b93d0deccd29d
# Instance rebooted: {"RequestId":"7A1C7CEC-65F0-3078-9752-FE322C5D1E14"}
# Instance renamed: {"RequestId":"44E7C851-EE30-3775-B2DF-DBF0F570CC81"}
# instance was rebooted
# 6. d0a3833b36164eba8d1698e63cd7c1f6
# Instance rebooted: {"RequestId":"3BF8B86D-9C3F-346D-A27C-B82947854555"}
# Instance renamed: {"RequestId":"82441189-E8E7-3CDD-B89D-98C36EB9D7D1"}
# instance was rebooted
# 7. 51bf03c4199c46c5afa466526881d389
# Instance rebooted: {"RequestId":"CCE6DE9F-4F48-35F1-B542-23A16C9504C3"}
# Instance renamed: {"RequestId":"01086144-8D1E-368F-A297-001B9A2957A9"}
# instance was rebooted
# 8. 8018dcf39e544bb2ac2488c0d4f6daa2
# Instance rebooted: {"RequestId":"1A8EBEB8-587C-39AA-8275-14B74544C598"}
# Instance renamed: {"RequestId":"C1AF771A-C472-35D6-AA7D-813C7242FEA2"}
# instance was rebooted
# 9. 6a302c1eec8741139899a419f1101513
# Instance rebooted: {"RequestId":"FCBA36C9-B3C9-3827-AA8A-5CB759233806"}
# Instance renamed: {"RequestId":"FECA9B2C-21DC-362A-B9EB-BC53E055A51A"}
# instance was rebooted
# 10. 6ab37c56fa41452aa4b6bf7216048d46
# Instance rebooted: {"RequestId":"306D2FD5-5DB8-3882-9E58-FD5AAF1CE7BB"}
# Instance renamed: {"RequestId":"C461C5D1-BBA4-3B3A-82D3-F8C5F23CD460"}
# instance was rebooted
# 11. e9129afd2af64c6d92427338df7f3829
# Instance rebooted: {"RequestId":"3C6FDE86-8C1D-3734-8856-8C4E19891AB5"}
# Instance renamed: {"RequestId":"5676BF50-08F1-3D51-93D5-F93BAEA13DFF"}
# instance was rebooted
# 12. b22b6016157442c3a672cb9b67efa340
# Instance rebooted: {"RequestId":"9ED4390E-36B2-3466-94C3-C4A20A9DFCC1"}
# Instance renamed: {"RequestId":"B6041995-4124-3A86-84BA-D1C3BCB2FB4C"}
# instance was rebooted
# 13. cd5ffb4984ef449f91e3eb37192cd7f4
# Instance rebooted: {"RequestId":"F75194D5-E893-3BF7-B0FC-0CFBEABC2CCB"}
# Instance renamed: {"RequestId":"10CC3EE8-6FC5-3B7F-84B0-492AEFB7F900"}
# instance was rebooted
# 14. b797b37688184ae69585d9b36e8c2e75
# Instance rebooted: {"RequestId":"D6621DF4-8A99-3D28-A93F-5194ECF233C9"}
# Instance renamed: {"RequestId":"370928A8-2586-3C16-B91D-370358002FB9"}
# instance was rebooted
# 15. a05f4ef83fe44d418d28bfc9fb77b06c
# Instance rebooted: {"RequestId":"95BDDB34-ECED-3706-95AD-8FDB4A1F551A"}
# Instance renamed: {"RequestId":"6ABCA1B2-56FD-3C72-BD99-695C7ABC3CA8"}
# instance was rebooted
# 16. 6a782d86ed784e90bbb07da3bbf388c6
# Instance rebooted: {"RequestId":"CFCC88B2-EBB9-3AB3-9CDE-DF159DEF8876"}
# Instance renamed: {"RequestId":"C8CFF8DA-058D-3634-BC40-5B77979E93B4"}
# instance was rebooted
# 17. aa0aec969ec94e69986ff07248dc75ad
# Instance rebooted: {"RequestId":"81594E3E-43ED-3D1B-BE91-2ACA6685AABA"}
# Instance renamed: {"RequestId":"62697929-A6AE-3F33-B6EA-B03267471E71"}
# instance was rebooted
# 18. de88128ee4d349c2a7d2de92fdf755ed
# Instance rebooted: {"RequestId":"DCB56FAE-2BC5-3323-8B4A-D5F46C48327A"}
# Instance renamed: {"RequestId":"4621CF96-0BC6-3100-88EA-377F61E1B731"}
# instance was rebooted
# 19. b651449c46c84ceabd0760e57d6797f6
# Instance rebooted: {"RequestId":"40E32624-3416-35BC-A196-DBA2337BAB5C"}
# Instance renamed: {"RequestId":"04BA3247-4A07-3931-8C26-E5BF8A222AF6"}
# instance was rebooted
# 20. 4ab44591456440e6888ac2b3130a5151
# 20. 3f362725b29d4943b894f98f6155c6db
# 20. 952dbd0188ff4603b94c81f69398ed75
# 20. 75e4db20cafe4da592a1d3bbed5f82ef
# 20. 0093ac7018f244d3aa2f0ebdd1b659e6
# Instance rebooted: {"RequestId":"3403748D-F0DB-32A9-8223-21384607DDD3"}
# Instance renamed: {"RequestId":"690D12F7-122C-3EFC-809C-1B19E44921D8"}
# instance was rebooted
# 21. 23f14675005049159f11e7c31a9a0bcc
# Instance rebooted: {"RequestId":"4E8D7D82-DEFD-332C-949D-3A9C41F6847C"}
# Instance renamed: {"RequestId":"20DC18DE-D3F5-3BAA-A738-F3A68C159368"}
# instance was rebooted
# 22. e953686357ad4162b953a9c0b30fc377
# Instance rebooted: {"RequestId":"7BDB08DB-A084-34FA-8731-F582AB760673"}
# Instance renamed: {"RequestId":"B40C27A7-18DB-376D-8D5E-855118A0F54C"}
# instance was rebooted
# 23. f0979785d7514234a309ca453263f810
# Instance rebooted: {"RequestId":"C5E8D7EF-B6A5-3132-AB25-61218AD76EC8"}
# Instance renamed: {"RequestId":"9915E8DF-F92A-384F-BDE6-E5D86B8355FD"}
# instance was rebooted
# 24. db84264efa2847838c8e7f8c4e00519e
# Instance rebooted: {"RequestId":"FB9A98D5-159E-37FA-94DA-0F13FE4AA1A3"}
# Instance renamed: {"RequestId":"0BFF2407-EA25-3709-ACF8-98FEB3FF5A48"}
# instance was rebooted
# 25. 44db2106eff84dbcb2ce55b5b9b22109
# Instance rebooted: {"RequestId":"5F62054A-CF75-346B-A65E-2D6D2715E888"}
# Instance renamed: {"RequestId":"AD02C582-F441-3577-9950-0026B7FD640D"}
# instance was rebooted
# 26. ced72dd327ad483cab89e36fc445ff19
# Instance rebooted: {"RequestId":"8B0E9D75-6351-36C7-8867-22D947E580F4"}
# Instance renamed: {"RequestId":"7E043E53-1BDD-3061-910B-6010A42F86F8"}
# instance was rebooted
# 27. 0a21c71e362744da97eb6b709ad17c4c
# Instance rebooted: {"RequestId":"311B5B8E-82A3-3F00-B366-57C192023A84"}
# Instance renamed: {"RequestId":"855CAB37-40B1-3E88-A70D-70CD4526BB4C"}
# instance was rebooted
# 28. fdf4f13b82a84273925d208d298d57ad
# Instance rebooted: {"RequestId":"2F40F9FE-349A-33E7-B035-6E3FAB8FD99F"}
# Instance renamed: {"RequestId":"47E3601A-6F9F-3FA4-8B76-56A0A3BEB407"}
# instance was rebooted
# 29. d921449534da47ceac537a38ac3895d1
# Instance rebooted: {"RequestId":"AD9B571B-79F0-34C3-9C52-C6813F0967C8"}
# Instance renamed: {"RequestId":"43DDF1BA-5562-3101-B811-B99512BE1DB1"}
# instance was rebooted
# 30. 0757258dda67410bba2a3d43155811e3
# Instance rebooted: {"RequestId":"C058C3AA-3FE7-31CC-84B0-CFAE36B5890E"}
# Instance renamed: {"RequestId":"5B40CE94-8ECA-3413-BC72-FD4C38BE1678"}
# instance was rebooted
# 31. 15f954c2897b4e9c9aa47d5cdd0bd162
# Instance rebooted: {"RequestId":"1B835B0D-C81B-3DE7-8E75-997674A414AF"}
# Instance renamed: {"RequestId":"E1B29790-45DA-3604-9B0B-6C294D9F11B0"}
# instance was rebooted
# 32. cd1407feb6834e6fb5a7426f0b5de432
# Instance rebooted: {"RequestId":"D18B224B-2C2B-37A5-A12C-588556B8D412"}
# Instance renamed: {"RequestId":"5A0DC19D-2512-3803-81C3-BA57558DDE23"}
# instance was rebooted
# 33. 2d34a08135c042a3b4f64e6f943551a0
# Instance rebooted: {"RequestId":"50AAA528-6A7E-3BC3-A83D-15CB12FA6C5D"}
# Instance renamed: {"RequestId":"865856A7-905E-312E-A66E-CB0087D5076C"}
# instance was rebooted
# 34. 30338f37db3c4276b96ec6fabe24eeac
# Instance rebooted: {"RequestId":"C464E1FE-BC92-3A6F-899B-D1CE9770B756"}
# Instance renamed: {"RequestId":"379160D7-7849-3DF4-BEF7-5092A9DAB77F"}
# instance was rebooted
# 35. 3f99e061557b40c285b4d1441e7f2838
# Instance rebooted: {"RequestId":"55B168B2-CBCB-3E23-AF3F-6D32BF26DF21"}
# Instance renamed: {"RequestId":"7B4450BF-ABA8-3836-B6DA-89BEA2279BBE"}
# instance was rebooted
# 36. d1e6ddac71844570b60d1accf4ff0c4b
# Instance rebooted: {"RequestId":"12288A4F-A716-314E-BFEE-324D23E70C24"}
# Instance renamed: {"RequestId":"AB8C4BF5-4F3F-3D3A-9652-A9AC4DF58F48"}
# instance was rebooted
# 37. f180891252e44603aaa6e6e8cae19fc8
# Instance rebooted: {"RequestId":"0728A7BE-280E-321C-90CF-821F9022225C"}
# Instance renamed: {"RequestId":"DE273441-85FF-36A3-A815-6C64A27CE1A4"}
# instance was rebooted
# 38. fcc2809b39154b43a6c2c4a6cc9470cd
# Instance rebooted: {"RequestId":"1C062E06-C77B-3654-A3B7-DFAD135E2AC1"}
# Instance renamed: {"RequestId":"B669C19E-0BFB-3AFA-A6FD-56D50384149A"}
# instance was rebooted
# 39. 8303c1e50db34cfd93cd904f48041bc0
# Instance rebooted: {"RequestId":"34E6B8C1-3611-37F7-B56E-347DB0A19EC4"}
# Instance renamed: {"RequestId":"FBF1DB47-7515-37E2-8FC3-E46559D3A1A6"}
# instance was rebooted
# 40. e69476244ad548ff87f7f4115785a3a6
# Instance rebooted: {"RequestId":"21D45B9A-9457-3938-8B2E-F9A0212C23BC"}
# Instance renamed: {"RequestId":"052BE39F-7EED-3C99-83B2-C20FD9E0B6DD"}
# instance was rebooted
# 41. 586979639b884e809084d63f2ba8a4f1
# Instance rebooted: {"RequestId":"3179CB8E-1836-34FB-8BDD-93746816FB7B"}
# Instance renamed: {"RequestId":"1CA864FB-9B01-3F22-B066-8BF53FDD96F1"}
# instance was rebooted
# 42. 8640e3a799934892abc7bf9c6153d9e9
# Instance rebooted: {"RequestId":"97DE94C4-519D-349A-9F8D-F6920EBD482D"}
# Instance renamed: {"RequestId":"B9FAA5C2-D45B-3491-A5EC-AE49F39CB31E"}
# instance was rebooted
# 43. 912b09f3bd8a4eabbb7807c67bb3b64f
# Instance rebooted: {"RequestId":"B3687E6D-F441-3197-9080-380AF1BFD264"}
# Instance renamed: {"RequestId":"484AFC51-61CA-3650-9CED-35D8415B6E8F"}
# instance was rebooted
# 44. 848f4faacdbb445ca9b21af1deb92bde
# Instance rebooted: {"RequestId":"69F39BF0-6C1C-38DA-86AA-D920B7B427D8"}
# Instance renamed: {"RequestId":"0ABA3CC8-C60E-3C62-AB33-30E00D055367"}
# instance was rebooted
# 45. 6c79db8c660c43a7ab62fc00c6f6ca9a
# Instance rebooted: {"RequestId":"16B2E74B-1686-383E-A907-BFF6F7708B05"}
# Instance renamed: {"RequestId":"A8C5062A-36CC-3ED3-8793-B95B3529DDDA"}
# instance was rebooted
# 46. 7f54d46ddd104051aa678d271baf67e2
# Instance rebooted: {"RequestId":"C7ED5477-E7A8-3A68-B805-51C2BA7EAB05"}
# Instance renamed: {"RequestId":"5696109F-9B00-3EDA-ADFC-E6B40B4E0275"}
# instance was rebooted
# 47. 62d93c40ad874de28a8597d5eb1d1a33
# Instance rebooted: {"RequestId":"440F74F0-EC75-3941-8481-E6768DCCAABE"}
# Instance renamed: {"RequestId":"FC33CA27-A678-3136-A7D0-D926F7EAB77C"}
# instance was rebooted
# 48. af48ba0bd579459dbb3d3379bfdb166e
# Instance rebooted: {"RequestId":"50757000-782B-3A05-861C-3E2C7EA0FC75"}
# Instance renamed: {"RequestId":"6CC4D89A-ECCF-30E4-BD99-EF06484198F2"}
# instance was rebooted
# 49. eb0a9e94383e4a9bafaaea38b6cbc962
# Instance rebooted: {"RequestId":"EA0BCEC5-5861-3E96-8192-6A08DA9B2B05"}
# Instance renamed: {"RequestId":"80321C15-DE51-3EB2-93AE-ACA381D82443"}
# instance was rebooted
# 50. 90bae26b82884d028a342473d6240d35
# Instance rebooted: {"RequestId":"716F80FC-3B20-3C80-B30B-CA65025B7F66"}
# Instance renamed: {"RequestId":"0A75E34E-AD3B-3BAC-A8DA-9FE3C928606A"}
# instance was rebooted
# 51. 65a34410d8a249bba7e0a9900a609e48
# Instance rebooted: {"RequestId":"905B5ED6-6458-380B-857E-5074E68B2315"}
# Instance renamed: {"RequestId":"52746EBC-C8FB-3745-A0F1-D9921909EDFF"}
# instance was rebooted
# 52. dbfeff198a134cb798caca2fe762ac30
# Instance rebooted: {"RequestId":"6D3BE2A2-896F-3EBA-A41C-C608C6CAB379"}
# Instance renamed: {"RequestId":"1BFF002B-1216-3D4C-BE40-B6FC688C9477"}
# instance was rebooted
# 53. 8de800e950b549be8f03c5d65a681b8e
# Instance rebooted: {"RequestId":"12CBD7D3-C9F5-3601-9571-14A17D17AFF5"}
# Instance renamed: {"RequestId":"9060022A-F783-3312-8414-BA26E2D287A3"}
# instance was rebooted
# 54. be2ae8ef9477415485e8ab25e6c92e2e
# Instance rebooted: {"RequestId":"A6E7EC0A-AC45-381C-A7AC-D14B81507ADD"}
# Instance renamed: {"RequestId":"06B7C281-FACA-32D1-8130-E2219C190E68"}
# instance was rebooted
# 55. e18c9e0b799c4c1fba53751b21fc891e
# Instance rebooted: {"RequestId":"FD18C2E9-24EA-3559-A00E-DBA00840744D"}
# Instance renamed: {"RequestId":"70289003-5B7A-3F9F-B162-F4B96F826D77"}
# instance was rebooted
# 56. 65046de9c75f4ff380bf2650e49c43ec
# Instance rebooted: {"RequestId":"F58E5260-753C-374B-BCB0-B60CCEA2CB94"}
# Instance renamed: {"RequestId":"7639045A-BFDC-38C8-9FD1-D353ADEA8B96"}
# instance was rebooted
# 57. f47eb41147504496a16aee5577a931e8
# Instance rebooted: {"RequestId":"E5C7F87F-F098-3521-9F74-DA9FDDBB867D"}
# Instance renamed: {"RequestId":"605FEC34-3B35-3383-A45C-B6D21D92D1E2"}
# instance was rebooted
# 58. 9f4bbf5762bb489ba8bca8fbfec70ba1
# Instance rebooted: {"RequestId":"DDFDB148-4D76-33FC-A4B0-4840C4BEB9FB"}
# Instance renamed: {"RequestId":"5F435126-4019-3372-9659-BE923CE6B17A"}
# instance was rebooted
# 59. fa814143ae1e45a49826571dcf563ab0
# Instance rebooted: {"RequestId":"A5661B27-E6A3-3220-A24C-0509B0240F1E"}
# Instance renamed: {"RequestId":"F590B051-0561-352D-96AF-F3918FE392D1"}
# instance was rebooted
# 60. b00de030720c4e24bdb2af7e01258d8a
# Instance rebooted: {"RequestId":"22D4B6CC-D3A2-32C1-B0FF-5AF37DDF34D9"}
# Instance renamed: {"RequestId":"873C03D7-4C62-3384-83BF-4028DD1DE429"}
# instance was rebooted
# 61. 475a8f4a10f4490ebfb4e4a4241a6300
# Instance rebooted: {"RequestId":"C0ED8248-6693-3485-98B5-8B6F51AA30CD"}
# Instance renamed: {"RequestId":"F1351011-51CC-303F-A885-A443B31F2C88"}
# instance was rebooted
# 62. c3dd8e6f55fd425b9ce757083cedabe9
# Instance rebooted: {"RequestId":"76C452C5-4A30-3855-92BE-1EF00EEA881E"}
# Instance renamed: {"RequestId":"B753CE45-2615-34F1-9E70-B008359EAD18"}
# instance was rebooted
# 63. b662337ae46e424d9defa2fa8892a9bd
# Instance rebooted: {"RequestId":"3205588A-4790-37F3-9E8A-7962DE62901A"}
# Instance renamed: {"RequestId":"F4D27E52-E191-3BEC-B75E-BE1D23C3BC57"}
# instance was rebooted
# 64. a22ec54cfe7445c0b403976fc8d3b3a9
# Instance rebooted: {"RequestId":"9DD68B64-9DE5-3410-B3B8-AA11875C43C0"}
# Instance renamed: {"RequestId":"3B4CE4CF-01A4-36D2-BDF1-B42486D5E4D1"}
# instance was rebooted
# 65. 7e03b54b65e042c285d2a856033f5a98
# Instance rebooted: {"RequestId":"AC1AE0F4-C4F7-3552-A71F-9B0A7C46CEC6"}
# Instance renamed: {"RequestId":"7CC03E76-F846-38D8-992C-3E45FF32514B"}
# instance was rebooted
# 66. ea3bce2f8bf04f329346026429cf9e9a
# Instance rebooted: {"RequestId":"279DC5E6-0724-3EC1-8D1E-5D8F5D90D55B"}
# Instance renamed: {"RequestId":"5F6FF8A0-336B-3AFD-B839-CECDC6B403F2"}
# instance was rebooted
# 67. dbad26b26e574585af5e9677953d42b5
# Instance rebooted: {"RequestId":"998C528A-E030-30EA-8C2E-DDE3ED9082F6"}
# Instance renamed: {"RequestId":"C2C513C3-08BA-3A1C-9BBD-9A60A29825E5"}
# instance was rebooted
# 68. 70b6c2ee060944b6b3bf1750b373197f
# Instance rebooted: {"RequestId":"840AC42D-3B4D-33AC-9C1F-F18831FCD217"}
# Instance renamed: {"RequestId":"E413FC4E-7CCD-35C1-8FE3-EBF8DBB90327"}
# instance was rebooted
# 69. c6a75e8ca3844994adede220da36033c
# Instance rebooted: {"RequestId":"E2810E33-7EFD-3F5C-8EE5-AA92448A0EF2"}
# Instance renamed: {"RequestId":"2B0C83C2-04C6-39AF-B7BA-EA841F65B4B0"}
# instance was rebooted
# 70. 366e0421c55d420e8d0acd334c10ea77
# Instance rebooted: {"RequestId":"24430506-0DEE-3F1F-9DCD-7B0F178C1F90"}
# Instance renamed: {"RequestId":"489185B5-EFE2-3FE9-8579-4B0A0275D072"}
# instance was rebooted
# 71. 3be97d190d4a44659664bd0d23fbaa81
# Instance rebooted: {"RequestId":"7D91C9B5-FB9D-3C61-ACF9-A7BB3B0AFC7A"}
# Instance renamed: {"RequestId":"5C4256B4-C744-38EA-AD99-5C780EF32E04"}
# instance was rebooted
# 72. 8505d9dee2e941669cdfdf55ad66e3a0
# Instance rebooted: {"RequestId":"D5AA4860-7154-377E-9CA2-E4451F0F07AE"}
# Instance renamed: {"RequestId":"72AF9956-1834-3D4A-B68A-CC2A3226628A"}
# instance was rebooted
# 73. 2324e0c904634fc997a50a7b4799a7fd
# Instance rebooted: {"RequestId":"95A8939C-07B4-336D-B0E5-88EE4984A461"}
# Instance renamed: {"RequestId":"55E6D79C-CEDB-3E72-8F55-02103F4B1433"}
# instance was rebooted
# 74. d2bc5c40b97c4a2c96246cb707c9d6e8
# Instance rebooted: {"RequestId":"481D912B-802E-3A25-BC8E-BECAD6215C94"}
# Instance renamed: {"RequestId":"89789BD6-BB09-3B19-8CA7-F0366B232504"}
# instance was rebooted
# 75. 86f570c821844675932b9c9ebb0a5506
# Instance rebooted: {"RequestId":"627DB356-709F-328D-AB72-900B3A7DF0AD"}
# Instance renamed: {"RequestId":"F055BC5D-4BD6-3878-8FDD-2244E471CCDE"}
# instance was rebooted
# 76. b913b3e502ff465085d1b77f18dc56e8
# Instance rebooted: {"RequestId":"983F8547-A1D2-30D2-88CF-009CF9A6966C"}
# Instance renamed: {"RequestId":"BFEA5D97-70CC-3E6D-8004-8A8E191A8EB7"}
# instance was rebooted
# 77. 5feb59f6dad54e42b58de0a727636692
# Instance rebooted: {"RequestId":"76E686E1-C6B6-38DE-AC62-FBE98E899EA1"}
# Instance renamed: {"RequestId":"51632732-2DB5-35FE-9E91-C343D4F0A6E9"}
# instance was rebooted
# 78. 97e180f8cb1d406790dc55e686cec99b
# Instance rebooted: {"RequestId":"2FD9A488-F692-3392-9B5E-CAC35FDDF017"}
# Instance renamed: {"RequestId":"A59CDA5E-05E2-33CA-B93D-E359D0830EDE"}
# instance was rebooted
# 79. 231b42c0dae84221a94c1e6730d380e2
# Instance rebooted: {"RequestId":"F2A58EE9-0768-39B8-AA09-3E9CA1598BF9"}
# Instance renamed: {"RequestId":"C5DD7D2C-759B-3520-A6E6-BCFBBDC3E5DA"}
# instance was rebooted
# 80. b6e38e5ffd8a479f870a88f31be75bff
# Instance rebooted: {"RequestId":"194FB608-EA97-3995-8ADD-B0113F3FD514"}
# Instance renamed: {"RequestId":"6BAFE5C8-314E-399D-9ED1-E608858E1E94"}
# instance was rebooted
# 81. 49631235d42544abb48c18b7868ddcfd
# Instance rebooted: {"RequestId":"9C6E3927-6AE6-3352-969E-3F23F648EBC1"}
# Instance renamed: {"RequestId":"F2E3D85B-0861-3473-9645-75E4F8B3A060"}
# instance was rebooted
# 82. 6c0fa18519a14ee4a6f70db77422cadd
# Instance rebooted: {"RequestId":"19CB8F8A-23F7-3B7D-B37F-82D8BF9B6A7C"}
# Instance renamed: {"RequestId":"4DEB98A7-A4D0-3FA8-846C-9BA1574E8B73"}
# instance was rebooted
# 83. 5fc7f5ab17c14edf99479b3891aebe18
# Instance rebooted: {"RequestId":"1C01B9E2-9095-30DD-8742-BB6D412F94D0"}
# Instance renamed: {"RequestId":"05039CD2-E778-327E-9821-E92B28CFF5B5"}
# instance was rebooted
# 84. 12ea8d103fb04bdd8d8302dd4a54c229
# Instance rebooted: {"RequestId":"8B351397-ABB3-3746-BACF-AB3D7869FC7A"}
# Instance renamed: {"RequestId":"85D3A4B4-D361-3436-AE9E-6020B389637A"}
# instance was rebooted
# 85. ec28697c88914fc99ab414e8b14a98f3
# Instance rebooted: {"RequestId":"653ADD0A-3F2B-3BAA-8872-16C60E95A19A"}
# Instance renamed: {"RequestId":"B0742EEC-AE49-30D3-8D2F-21E06E2DE27B"}
# instance was rebooted
# 86. 3f211cdb0eaa47f9822bc805968d439a
# Instance rebooted: {"RequestId":"DEB68121-D53C-3F3B-B971-D383161E4A0F"}
# Instance renamed: {"RequestId":"6BC84F8A-E0A2-33EE-A866-BD349B74F4CF"}
# instance was rebooted
# 87. 162776bfcada483bba93e0f46a2fb507
# Instance rebooted: {"RequestId":"D7F1A2B8-78E6-31FA-A32D-039646C6FC3F"}
# Instance renamed: {"RequestId":"99279072-00B1-3BEE-9ACD-6E84E032FFDB"}
# instance was rebooted
# 88. a60d2cd88c8441b6a47487c998cb0227
# Instance rebooted: {"RequestId":"752C0A86-4875-3481-A870-5F34EAD6CFE2"}
# Instance renamed: {"RequestId":"21223613-FD5D-3068-B22C-2B25DB35A385"}
# instance was rebooted
# 89. 8f7f441302534dda8f1663541ec72ac0
# Instance rebooted: {"RequestId":"7249D5B0-9C05-3908-9722-552F6D90F5F3"}
# Instance renamed: {"RequestId":"38E4534D-22AF-3E10-B9C8-F1231C017C6E"}
# instance was rebooted
# 90. 50694e0c23e744a18dea983c5bf3c530
# Instance rebooted: {"RequestId":"F4AED230-FBB2-30D7-8FCB-1C06A1D74E2E"}
# Instance renamed: {"RequestId":"051C1670-6AA8-31D6-ACDE-0CADB46ECB46"}
# instance was rebooted
# 91. 51460ac75e08473ea3befc7bf7727839
# Instance rebooted: {"RequestId":"8692C8F0-634A-3E29-B6FA-9EA9AA3D848C"}
# Instance renamed: {"RequestId":"71E9D07C-9092-38B7-A9E9-47BB4663B16F"}
# instance was rebooted
# 92. aacc7b6360d841e99c2ba659a6382b54
# Instance rebooted: {"RequestId":"16542F2D-C8F0-3365-8EEE-B98422F5D079"}
# Instance renamed: {"RequestId":"48B977A7-B62C-3844-84EC-FCD13A0FB61F"}
# instance was rebooted
# 93. 64b448095ec54bc4b6d4cc7c73c2b625
# Instance rebooted: {"RequestId":"0895A169-AED8-3A19-8A1E-1D351C014F09"}
# Instance renamed: {"RequestId":"D9DD9C29-1400-3890-A8B1-52F481897966"}
# instance was rebooted
# 94. 6bd5fcea3e434c30851be5156e9acc2c
# Instance rebooted: {"RequestId":"5EC8ED8F-CDA8-3BEE-8F8D-10CDCB923D5C"}
# Instance renamed: {"RequestId":"8F3FECEF-082E-31E6-AE13-81910F8210D2"}
# instance was rebooted
# 95. 0622783f38bf4515a3a39736dfbe1e6e
# Instance rebooted: {"RequestId":"D82C7BA5-1864-3590-859A-8C0E99ECD5DD"}
# Instance renamed: {"RequestId":"7CA7A4E2-9406-3D5E-88A4-88E56731ADC6"}
# instance was rebooted
# 96. 468ba7774e344abdba07ba1422a5b0a3
# Instance rebooted: {"RequestId":"CA0D075E-0513-3CF1-AFF9-4982D394B374"}
# Instance renamed: {"RequestId":"75A48D74-6E3C-3F94-A67B-92418471152C"}
# instance was rebooted
# 97. b841356c1a9f44a9a6e3cd0ebf190e34
# Instance rebooted: {"RequestId":"14F4D459-3934-304D-9B24-46420A259EA4"}
# Instance renamed: {"RequestId":"D9A53B93-C85D-339D-9E5E-DA82DBADA235"}
# instance was rebooted
# 98. 0b0e9429c23e43aeafedde0650cd1692
# Instance rebooted: {"RequestId":"E00984A9-9320-3469-B39B-AC10664BDA1B"}
# Instance renamed: {"RequestId":"AABEAB95-34E1-3BB7-B4A5-2FA9BCFE09DA"}
# instance was rebooted
# 99. 5fe802adffff4d2ba2cd14e976f329d7
# Instance rebooted: {"RequestId":"5C926F6C-C8EF-3040-9DD7-319D4F27A01D"}
# Instance renamed: {"RequestId":"92BAACC3-FEFD-3411-A3A8-DDEA70CD6828"}
# instance was rebooted
# 100. 9d4c9fd55d884badba2540b561432c1e
